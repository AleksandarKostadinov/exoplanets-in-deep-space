# %%
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
np.random.seed(5)

# %% [markdown]
# ## Read Data

# %%
exoTest = pd.read_table("Data/exoTest.csv", sep=',')

# %%
exoTrain = pd.read_table("Data/exoTrain.csv", sep=',')

# %%
exoTrain.head(n=5,)
# Out:
#    LABEL   FLUX.1   FLUX.2   FLUX.3   FLUX.4   FLUX.5   FLUX.6  FLUX.7  \
# 0      2    93.85    83.81    20.10   -26.98   -39.56  -124.71 -135.18
# 1      2   -38.88   -33.83   -58.54   -40.09   -79.31   -72.81  -86.55
# 2      2   532.64   535.92   513.73   496.92   456.45   466.00  464.50
# 3      2   326.52   347.39   302.35   298.13   317.74   312.70  322.33
# 4      2 -1107.21 -1112.59 -1118.95 -1095.10 -1057.55 -1034.48 -998.34
#
#     FLUX.8  FLUX.9    ...      FLUX.3188  FLUX.3189  FLUX.3190  FLUX.3191  \
# 0   -96.27  -79.89    ...         -78.07    -102.15    -102.15      25.13
# 1   -85.33  -83.97    ...          -3.28     -32.21     -32.21     -24.89
# 2   486.39  436.56    ...         -71.69      13.31      13.31     -29.89
# 3   311.31  312.42    ...           5.71      -3.73      -3.73      30.05
# 4 -1022.71 -989.57    ...        -594.37    -401.66    -401.66    -357.24
#
#    FLUX.3192  FLUX.3193  FLUX.3194  FLUX.3195  FLUX.3196  FLUX.3197
# ...

# %%
def get_features_and_labes (data):
    return (data.drop(['LABEL'], axis=1), data.LABEL)

# %%
features_train, lables_train = get_features_and_labes(exoTrain)

# %%
time_axis = np.linspace(0, 3197, num=3198, endpoint=True)
time_axis
# Out:
# array([  0.00000000e+00,   1.00000000e+00,   2.00000000e+00, ...,
#          3.19500000e+03,   3.19600000e+03,   3.19700000e+03])

# %%
plt.rcParams['figure.figsize'] = [10, 5]

# %%
def plot_flux(row, i):
    plt.title((i, 'row in time'))
    plt.plot(time_axis, row, color='lightblue', linewidth=.7)
    plt.show()

# %%
for i in range(0, 8):
    plot_flux(exoTrain.values[i], i)
